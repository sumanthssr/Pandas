# %%
import pandas as pd
df = pd.read_csv('nyc_weather.csv')
df
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
df['Temperature'].max()
# Out:
# 50

# %%
df.columns
# Out:
# Index(['EST', 'Temperature', 'DewPoint', 'Humidity', 'Sea Level PressureIn',
#        'VisibilityMiles', 'WindSpeedMPH', 'PrecipitationIn', 'CloudCover',
#        'Events', 'WindDirDegrees'],
#       dtype='object')

# %%
df.shape
# Out:
# (31, 11)

# %%
df['EST'][df['Events']=='Rain']
# Out:
# 8      1/9/2016
# 9     1/10/2016
# 15    1/16/2016
# 26    1/27/2016
# Name: EST, dtype: object

# %%
df['WindSpeedMPH'].mean()
# Out:
# 6.892857142857143

# %%
import numpy as np
arr = np.array(df)

# %%
EST,Temperature,DewPoint,Humidity,SeaLevelPressureIn,VisibilityMiles,WindSpeedMPH,PrecipitationIn,CloudCover,Events,WindDirDegrees = arr.T

# %%
DewPoint
# Out:
# array([23, 18, 21, 9, -3, 4, 11, 29, 38, 46, 8, 15, 4, 12, 31, 37, 23, 6,
#        3, 15, 11, 6, 21, 11, 18, 29, 22, 20, 21, 16, 28], dtype=object)

# %%
weather_df = pd.read_csv('weather_data.csv')
weather_df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
data=pd.DataFrame({'day':['2/2/2018','3/2/2018'],'temperature':[32,33],'windspeed':[4,5],'event':['Rain','Sunny']})
weather_df.append(data,ignore_index=True)
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny
# 6  2/2/2018           32          4   Rain
# 7  3/2/2018           33          5  Sunny

# %%
weather_df['NewCol'] = None

# %%
weather_df
# Out:
#         day  temperature  windspeed  event NewCol
# 0  1/1/2017           32          6   Rain   None
# 1  1/2/2017           35          7  Sunny   None
# 2  1/3/2017           28          2   Snow   None
# 3  1/4/2017           24          7   Snow   None
# 4  1/5/2017           32          4   Rain   None
# 5  1/6/2017           31          2  Sunny   None

# %%
weather_df.tail()
# Out:
#         day  temperature  windspeed  event NewCol
# 1  1/2/2017           35          7  Sunny   None
# 2  1/3/2017           28          2   Snow   None
# 3  1/4/2017           24          7   Snow   None
# 4  1/5/2017           32          4   Rain   None
# 5  1/6/2017           31          2  Sunny   None

# %%
weather_df[2:4]
# Out:
#         day  temperature  windspeed event NewCol
# 2  1/3/2017           28          2  Snow   None
# 3  1/4/2017           24          7  Snow   None

# %%
weather_df.day
# Out:
# 0    1/1/2017
# 1    1/2/2017
# 2    1/3/2017
# 3    1/4/2017
# 4    1/5/2017
# 5    1/6/2017
# Name: day, dtype: object

# %%
import pandas as pd
df= pd.read_csv('nba.csv')

df
# Out:
#                         Name                    Team  Number Position   Age  \
# 0              Avery Bradley          Boston Celtics     0.0       PG  25.0
# 1                Jae Crowder          Boston Celtics    99.0       SF  25.0
# 2               John Holland          Boston Celtics    30.0       SG  27.0
# 3                R.J. Hunter          Boston Celtics    28.0       SG  22.0
# 4              Jonas Jerebko          Boston Celtics     8.0       PF  29.0
# 5               Amir Johnson          Boston Celtics    90.0       PF  29.0
# 6              Jordan Mickey          Boston Celtics    55.0       PF  21.0
# 7               Kelly Olynyk          Boston Celtics    41.0        C  25.0
# 8               Terry Rozier          Boston Celtics    12.0       PG  22.0
# 9               Marcus Smart          Boston Celtics    36.0       PG  22.0
# 10           Jared Sullinger          Boston Celtics     7.0        C  24.0
# ...

# %%
data = pd.read_csv("nba.csv", index_col ="Name")
 
# retrieving row by loc method
first = data.iloc[456]
print(first)
# Out:
# Team        Utah Jazz
# Number             24
# Position            C
# Age                26
# Height            7-0
# Weight            231
# College        Kansas
# Salary         947276
# Name: Jeff Withey, dtype: object

# %%
first = data.loc["Jeff Withey"]
print(first)
# Out:
# Team        Utah Jazz
# Number             24
# Position            C
# Age                26
# Height            7-0
# Weight            231
# College        Kansas
# Salary         947276
# Name: Jeff Withey, dtype: object

# %%
# importing pandas as pd
import pandas as pd
   
# dictionary of lists
dict = {'name':["aparna", "pankaj", "sudhir", "Geeku"],
        'degree': ["MBA", "BCA", "M.Tech", "MBA"],
        'score':[90, 40, 80, 98]}
  
# creating a dataframe from a dictionary 
df = pd.DataFrame(dict)
 
print(df)
# Out:
#      name  degree  score
# 0  aparna     MBA     90
# 1  pankaj     BCA     40
# 2  sudhir  M.Tech     80
# 3   Geeku     MBA     98

# %%
columns = list(df)
columns
# Out:
# ['name', 'degree', 'score']

# %%
for i,j in df.iterrows():
    print(j)
# Out:
# name      aparna
# degree       MBA
# score         90
# Name: 0, dtype: object
# name      pankaj
# degree       BCA
# score         40
# Name: 1, dtype: object
# name      sudhir
# degree    M.Tech
# score         80
# Name: 2, dtype: object
# name      Geeku
# degree      MBA
# score        98
# Name: 3, dtype: object

# %%
for i in columns:
    print(df[i][2])
# Out:
# sudhir
# M.Tech
# 80

# %%
df
# Out:
#      name  degree  score
# 0  aparna     MBA     90
# 1  pankaj     BCA     40
# 2  sudhir  M.Tech     80
# 3   Geeku     MBA     98

# %%
df.insert(3,'Team','Any')

# %%
df
# Out:
#      name  degree  score Team
# 0  aparna     MBA     90  Any
# 1  pankaj     BCA     40  Any
# 2  sudhir  M.Tech     80  Any
# 3   Geeku     MBA     98  Any

# %%
len(df)
# Out:
# 4

# %%
new_type = pd.Series([])
for i in range(len(df)):
    if df['score'][i] > 35:
        new_type[i]='pass'
    else:
        new_type[i]='fail'
        
df.insert(4,'Result',new_type)
df
# Out:
#      name  degree  score Team Result
# 0  aparna     MBA     90  Any   pass
# 1  pankaj     BCA     40  Any   pass
# 2  sudhir  M.Tech     80  Any   pass
# 3   Geeku     MBA     98  Any   pass

# %%
df= pd.read_csv('weather_data.csv')
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
new_val = pd.Series([])
for i in range(len(df)):
    if df['event'][i]=='Rain':
        new_val[i]="Can Play"
    else:
        new_val[i]="Can't Play"
df.insert(4,'Result2',new_val)

# %%
df
# Out:
#         day  temperature  windspeed  event     Result2
# 0  1/1/2017           32          6   Rain    Can Play
# 1  1/2/2017           35          7  Sunny  Can't Play
# 2  1/3/2017           28          2   Snow  Can't Play
# 3  1/4/2017           24          7   Snow  Can't Play
# 4  1/5/2017           32          4   Rain    Can Play
# 5  1/6/2017           31          2  Sunny  Can't Play

# %%
import numpy as np
np.random.seed(10)
df1= pd.DataFrame(np.random.rand(10,3),columns=['A','B','C'])
df2= pd.DataFrame(np.random.rand(5,5),columns=['A','B','C','D','E'])

# %%
df1
# Out:
#           A         B         C
# 0  0.771321  0.020752  0.633648
# 1  0.748804  0.498507  0.224797
# 2  0.198063  0.760531  0.169111
# 3  0.088340  0.685360  0.953393
# 4  0.003948  0.512192  0.812621
# 5  0.612526  0.721755  0.291876
# 6  0.917774  0.714576  0.542544
# 7  0.142170  0.373341  0.674134
# 8  0.441833  0.434014  0.617767
# 9  0.513138  0.650397  0.601039

# %%
df2
# Out:
#           A         B         C         D         E
# 0  0.805223  0.521647  0.908649  0.319236  0.090459
# 1  0.300700  0.113984  0.828681  0.046896  0.626287
# 2  0.547586  0.819287  0.198948  0.856850  0.351653
# 3  0.754648  0.295962  0.883936  0.325512  0.165016
# 4  0.392529  0.093460  0.821106  0.151152  0.384114

# %%
df1.add(df2,fill_value=0)
# Out:
#           A         B         C         D         E
# 0  1.576544  0.542399  1.542297  0.319236  0.090459
# 1  1.049504  0.612491  1.053478  0.046896  0.626287
# 2  0.745649  1.579818  0.368058  0.856850  0.351653
# 3  0.842988  0.981322  1.837330  0.325512  0.165016
# 4  0.396478  0.605653  1.633727  0.151152  0.384114
# 5  0.612526  0.721755  0.291876       NaN       NaN
# 6  0.917774  0.714576  0.542544       NaN       NaN
# 7  0.142170  0.373341  0.674134       NaN       NaN
# 8  0.441833  0.434014  0.617767       NaN       NaN
# 9  0.513138  0.650397  0.601039       NaN       NaN

# %%
df1.add(1)
# Out:
#           A         B         C
# 0  1.771321  1.020752  1.633648
# 1  1.748804  1.498507  1.224797
# 2  1.198063  1.760531  1.169111
# 3  1.088340  1.685360  1.953393
# 4  1.003948  1.512192  1.812621
# 5  1.612526  1.721755  1.291876
# 6  1.917774  1.714576  1.542544
# 7  1.142170  1.373341  1.674134
# 8  1.441833  1.434014  1.617767
# 9  1.513138  1.650397  1.601039

# %%
df1.iloc[-1] = np.nan

# %%
df1
# Out:
#           A         B         C
# 0  0.771321  0.020752  0.633648
# 1  0.748804  0.498507  0.224797
# 2  0.198063  0.760531  0.169111
# 3  0.088340  0.685360  0.953393
# 4  0.003948  0.512192  0.812621
# 5  0.612526  0.721755  0.291876
# 6  0.917774  0.714576  0.542544
# 7  0.142170  0.373341  0.674134
# 8  0.441833  0.434014  0.617767
# 9       NaN       NaN       NaN

# %%
df1.dropna()
# Out:
#           A         B         C
# 0  0.771321  0.020752  0.633648
# 1  0.748804  0.498507  0.224797
# 2  0.198063  0.760531  0.169111
# 3  0.088340  0.685360  0.953393
# 4  0.003948  0.512192  0.812621
# 5  0.612526  0.721755  0.291876
# 6  0.917774  0.714576  0.542544
# 7  0.142170  0.373341  0.674134
# 8  0.441833  0.434014  0.617767

# %%
s = pd.Series(np.ones(9))
s
# Out:
# 0    1.0
# 1    1.0
# 2    1.0
# 3    1.0
# 4    1.0
# 5    1.0
# 6    1.0
# 7    1.0
# 8    1.0
# dtype: float64

# %%
df1.add(s,axis='index')
# Out:
#           A         B         C
# 0  1.771321  1.020752  1.633648
# 1  1.748804  1.498507  1.224797
# 2  1.198063  1.760531  1.169111
# 3  1.088340  1.685360  1.953393
# 4  1.003948  1.512192  1.812621
# 5  1.612526  1.721755  1.291876
# 6  1.917774  1.714576  1.542544
# 7  1.142170  1.373341  1.674134
# 8  1.441833  1.434014  1.617767
# 9       NaN       NaN       NaN

# %%
df3 = pd.DataFrame(np.random.rand(5,3),columns = ['A','B','C'])
df4 = pd.Series([12,12,31],index=['A','B','C'])

# %%
df4
# Out:
# A    12
# B    12
# C    31
# dtype: int64

# %%
df3
# Out:
#           A         B         C
# 0  0.025400  0.303063  0.242076
# 1  0.557578  0.565507  0.475132
# 2  0.292798  0.064251  0.978819
# 3  0.339708  0.495049  0.977081
# 4  0.440774  0.318273  0.519797

# %%
df3.div(df4,axis=1)
# Out:
#           A         B         C
# 0  0.048178  0.071161  0.002197
# 1  0.038711  0.065162  0.023181
# 2  0.048835  0.003091  0.011311
# 3  0.046933  0.024977  0.016527
# 4  0.056122  0.013266  0.001628

# %%
df
# Out:
#         day  temperature  windspeed  event     Result2
# 0  1/1/2017           32          6   Rain    Can Play
# 1  1/2/2017           35          7  Sunny  Can't Play
# 2  1/3/2017           28          2   Snow  Can't Play
# 3  1/4/2017           24          7   Snow  Can't Play
# 4  1/5/2017           32          4   Rain    Can Play
# 5  1/6/2017           31          2  Sunny  Can't Play

# %%
df1
# Out:
#           A         B         C
# 0  0.771321  0.020752  0.633648
# 1  0.748804  0.498507  0.224797
# 2  0.198063  0.760531  0.169111
# 3  0.088340  0.685360  0.953393
# 4  0.003948  0.512192  0.812621
# 5  0.612526  0.721755  0.291876
# 6  0.917774  0.714576  0.542544
# 7  0.142170  0.373341  0.674134
# 8  0.441833  0.434014  0.617767
# 9       NaN       NaN       NaN

# %%
df5 = pd.DataFrame({"A":[14, 4, 5, 4, 1], 
                   "B":[5, 2, 54, 3, 2], 
                   "C":[20, 20, 7, 3, 8], 
                    "D":[14, 3, 6, 2, 6]}) 
df5
# Out:
#     A   B   C   D
# 0  14   5  20  14
# 1   4   2  20   3
# 2   5  54   7   6
# 3   4   3   3   2
# 4   1   2   8   6

# %%
df5.nunique(axis=1)
# Out:
# 0    3
# 1    4
# 2    4
# 3    3
# 4    4
# dtype: int64

# %%
df1
# Out:
#           A         B         C
# 0  0.771321  0.020752  0.633648
# 1  0.748804  0.498507  0.224797
# 2  0.198063  0.760531  0.169111
# 3  0.088340  0.685360  0.953393
# 4  0.003948  0.512192  0.812621
# 5  0.612526  0.721755  0.291876
# 6  0.917774  0.714576  0.542544
# 7  0.142170  0.373341  0.674134
# 8  0.441833  0.434014  0.617767
# 9       NaN       NaN       NaN

# %%
df = pd.read_csv('employees.csv')
df
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# 5       Dennis    Male   4/18/1987         1:35 AM  115163   10.125
# 6         Ruby  Female   8/17/1987         4:20 PM   65476   10.012
# 7          NaN  Female   7/20/2015        10:43 AM   45906   11.598
# 8       Angela  Female  11/22/2005         6:29 AM   95570   18.523
# 9      Frances  Female    8/8/2002         6:51 AM  139852    7.524
# 10      Louise  Female   8/12/1980         9:01 AM   63241   15.132
# 11       Julie  Female  10/26/1997         3:19 PM  102508   12.637
# 12     Brandon    Male   12/1/1980         1:08 AM  112807   17.492
# ...

# %%
result = pd.notnull(df['Gender'])
df = df[result]
df
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# 5       Dennis    Male   4/18/1987         1:35 AM  115163   10.125
# 6         Ruby  Female   8/17/1987         4:20 PM   65476   10.012
# 7          NaN  Female   7/20/2015        10:43 AM   45906   11.598
# 8       Angela  Female  11/22/2005         6:29 AM   95570   18.523
# 9      Frances  Female    8/8/2002         6:51 AM  139852    7.524
# 10      Louise  Female   8/12/1980         9:01 AM   63241   15.132
# 11       Julie  Female  10/26/1997         3:19 PM  102508   12.637
# 12     Brandon    Male   12/1/1980         1:08 AM  112807   17.492
# ...

# %%
result = pd.notnull(df['Team'])
df = df[result]
df
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# 5       Dennis    Male   4/18/1987         1:35 AM  115163   10.125
# 6         Ruby  Female   8/17/1987         4:20 PM   65476   10.012
# 7          NaN  Female   7/20/2015        10:43 AM   45906   11.598
# 8       Angela  Female  11/22/2005         6:29 AM   95570   18.523
# 9      Frances  Female    8/8/2002         6:51 AM  139852    7.524
# 11       Julie  Female  10/26/1997         3:19 PM  102508   12.637
# 12     Brandon    Male   12/1/1980         1:08 AM  112807   17.492
# 13        Gary    Male   1/27/2008        11:40 PM  109831    5.831
# 14    Kimberly  Female   1/14/1999         7:13 AM   41426   14.543
# ...

# %%
result = pd.notnull(df['First Name'])
df[result]
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# 5       Dennis    Male   4/18/1987         1:35 AM  115163   10.125
# 6         Ruby  Female   8/17/1987         4:20 PM   65476   10.012
# 8       Angela  Female  11/22/2005         6:29 AM   95570   18.523
# 9      Frances  Female    8/8/2002         6:51 AM  139852    7.524
# 11       Julie  Female  10/26/1997         3:19 PM  102508   12.637
# 12     Brandon    Male   12/1/1980         1:08 AM  112807   17.492
# 13        Gary    Male   1/27/2008        11:40 PM  109831    5.831
# 14    Kimberly  Female   1/14/1999         7:13 AM   41426   14.543
# 15     Lillian  Female    6/5/2016         6:09 AM   59414    1.256
# ...

# %%
result = df['Gender'].isin(['Female'])
df[result]
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 6         Ruby  Female   8/17/1987         4:20 PM   65476   10.012
# 7          NaN  Female   7/20/2015        10:43 AM   45906   11.598
# 8       Angela  Female  11/22/2005         6:29 AM   95570   18.523
# 9      Frances  Female    8/8/2002         6:51 AM  139852    7.524
# 11       Julie  Female  10/26/1997         3:19 PM  102508   12.637
# 14    Kimberly  Female   1/14/1999         7:13 AM   41426   14.543
# 15     Lillian  Female    6/5/2016         6:09 AM   59414    1.256
# 18       Diana  Female  10/23/1981        10:27 AM  132940   19.082
# 19       Donna  Female   7/22/2010         3:48 AM   81014    1.894
# 30   Christina  Female    8/6/2002         1:19 PM  118780    9.096
# 33        Jean  Female  12/18/1993         9:07 AM  119082   16.180
# 35     Theresa  Female  10/10/2006         1:12 AM   85182   16.675
# ...

# %%
result = df['Gender'].isin(['Male'])
df[result]
# Out:
#     First Name Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas   Male    8/6/1993        12:42 PM   97308    6.945
# 3        Jerry   Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry   Male   1/24/1998         4:47 PM  101004    1.389
# 5       Dennis   Male   4/18/1987         1:35 AM  115163   10.125
# 12     Brandon   Male   12/1/1980         1:08 AM  112807   17.492
# 13        Gary   Male   1/27/2008        11:40 PM  109831    5.831
# 16      Jeremy   Male   9/21/2010         5:56 AM   90370    7.369
# 17       Shawn   Male   12/7/1986         7:45 PM  111737    6.414
# 21     Matthew   Male    9/5/1995         2:12 AM  100612   13.645
# 24        John   Male    7/1/1992        10:08 PM   97950   13.873
# 25         NaN   Male   10/8/2012         1:12 AM   37076   18.576
# 26       Craig   Male   2/27/2000         7:45 AM   37598    7.757
# 28       Terry   Male  11/27/1981         6:30 PM  124008   13.464
# ...

# %%
result1= df['Team'].isin(['Marketing'])
result2= df['Gender'].isin(['Male'])
(df[result1 & result2])
# Out:
#     First Name Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas   Male    8/6/1993        12:42 PM   97308    6.945
# 21     Matthew   Male    9/5/1995         2:12 AM  100612   13.645
# 26       Craig   Male   2/27/2000         7:45 AM   37598    7.757
# 74      Thomas   Male    6/4/1995         2:24 PM   62096   17.029
# 77     Charles   Male   9/14/2004         8:13 PM  107391    1.260
# 101      Aaron   Male   2/17/2012        10:20 AM   61602   11.849
# 104       John   Male  12/23/1989         7:01 AM   80740   19.305
# 112     Willie   Male  11/27/2003         6:21 AM   64363    4.023
# 119       Paul   Male    6/3/2008         3:05 PM   41054   12.299
# 150       Sean   Male    5/4/1996         8:59 PM  135490   19.934
# 187      Roger   Male  11/19/2004         3:55 PM   51430    6.460
# 204     Willie   Male    6/6/2006         9:45 AM   55281    4.935
# 216    Matthew   Male   7/31/2013         8:04 AM  142373    2.462
# ...

# %%
type(df.Salary[0])
# Out:
# numpy.int64

# %%
df.Salary.astype('float64')
# Out:
# 0       97308.0
# 2      130590.0
# 3      138705.0
# 4      101004.0
# 5      115163.0
# 6       65476.0
# 7       45906.0
# 8       95570.0
# 9      139852.0
# 11     102508.0
# 12     112807.0
# 13     109831.0
# 14      41426.0
# 15      59414.0
# 16      90370.0
# 17     111737.0
# 18     132940.0
# 19      81014.0
# 21     100612.0
# 24      97950.0
# 25      37076.0
# 26      37598.0
# 28     124008.0
# 29      79529.0
# 30     118780.0
# 33     119082.0
# 34      95734.0
# 35      85182.0
# 36     142032.0
# 37      57427.0
#          ...
# 966     93022.0
# 967    105681.0
# 968     43050.0
# 969     44486.0
# 970     63571.0
# 971     75423.0
# 973    137359.0
# 974     67656.0
# 975     92436.0
# 976    137954.0
# 977    124566.0
# 978     66146.0
# 979    142935.0
# 980     46233.0
# 981    148985.0
# 982     91411.0
# 983    146907.0
# 984     43455.0
# 986     82871.0
# 987    136709.0
# 988     47638.0
# 990    100765.0
# 991    134505.0
# 992    112769.0
# ...

# %%
df.sort_values('Salary',axis=0,ascending=True,na_position='last')
# Out:
#      First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 576     Michael    Male   7/30/1993         5:35 PM   35013   14.879
# 238       Kevin    Male   3/25/1982         7:31 AM   35061    5.128
# 82       Steven    Male   3/30/1980         9:20 PM   35095    8.379
# 63      Matthew    Male    1/2/2013        10:33 PM   35203   18.040
# 650     Cynthia  Female    7/5/1986         1:24 AM   35381   11.749
# 900   Christina  Female   6/23/2002         3:18 PM   35477   18.178
# 530    Kathleen  Female   6/13/2014         9:16 AM   35575   14.595
# 762       Terry    Male  11/10/2004         4:33 AM   35633    3.947
# 964       Bruce    Male    5/7/1980         8:00 PM   35802   12.391
# 906     Frances  Female   5/16/2014         8:31 AM   35884   17.667
# 198       Maria  Female  12/27/1990         9:57 PM   36067    9.640
# 418       Julia  Female    3/2/1982        12:52 PM   36403    2.664
# 201    Kimberly  Female   7/15/1997         5:57 AM   36643    7.953
# ...

# %%
df.sort_values(['Salary','Bonus %'],axis=0,ascending=[True,True],na_position='last')
# Out:
#      First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 576     Michael    Male   7/30/1993         5:35 PM   35013   14.879
# 238       Kevin    Male   3/25/1982         7:31 AM   35061    5.128
# 82       Steven    Male   3/30/1980         9:20 PM   35095    8.379
# 63      Matthew    Male    1/2/2013        10:33 PM   35203   18.040
# 650     Cynthia  Female    7/5/1986         1:24 AM   35381   11.749
# 900   Christina  Female   6/23/2002         3:18 PM   35477   18.178
# 530    Kathleen  Female   6/13/2014         9:16 AM   35575   14.595
# 762       Terry    Male  11/10/2004         4:33 AM   35633    3.947
# 964       Bruce    Male    5/7/1980         8:00 PM   35802   12.391
# 906     Frances  Female   5/16/2014         8:31 AM   35884   17.667
# 198       Maria  Female  12/27/1990         9:57 PM   36067    9.640
# 418       Julia  Female    3/2/1982        12:52 PM   36403    2.664
# 201    Kimberly  Female   7/15/1997         5:57 AM   36643    7.953
# ...

# %%
df.sort_index()
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# 5       Dennis    Male   4/18/1987         1:35 AM  115163   10.125
# 6         Ruby  Female   8/17/1987         4:20 PM   65476   10.012
# 7          NaN  Female   7/20/2015        10:43 AM   45906   11.598
# 8       Angela  Female  11/22/2005         6:29 AM   95570   18.523
# 9      Frances  Female    8/8/2002         6:51 AM  139852    7.524
# 11       Julie  Female  10/26/1997         3:19 PM  102508   12.637
# 12     Brandon    Male   12/1/1980         1:08 AM  112807   17.492
# 13        Gary    Male   1/27/2008        11:40 PM  109831    5.831
# 14    Kimberly  Female   1/14/1999         7:13 AM   41426   14.543
# ...

# %%
df = pd.read_csv('nba.csv',index_col ="Name")

df
# Out:
#                                            Team  Number Position   Age Height  \
# Name
# Avery Bradley                    Boston Celtics     0.0       PG  25.0    6-2
# Jae Crowder                      Boston Celtics    99.0       SF  25.0    6-6
# John Holland                     Boston Celtics    30.0       SG  27.0    6-5
# R.J. Hunter                      Boston Celtics    28.0       SG  22.0    6-5
# Jonas Jerebko                    Boston Celtics     8.0       PF  29.0   6-10
# Amir Johnson                     Boston Celtics    90.0       PF  29.0    6-9
# Jordan Mickey                    Boston Celtics    55.0       PF  21.0    6-8
# Kelly Olynyk                     Boston Celtics    41.0        C  25.0    7-0
# Terry Rozier                     Boston Celtics    12.0       PG  22.0    6-2
# Marcus Smart                     Boston Celtics    36.0       PG  22.0    6-4
# Jared Sullinger                  Boston Celtics     7.0        C  24.0    6-9
# ...

# %%
df.loc['Raul Neto':'Jeff Withey']
# Out:
#                    Team  Number Position   Age Height  Weight College  \
# Name
# Raul Neto     Utah Jazz    25.0       PG  24.0    6-1   179.0     NaN
# Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# Jeff Withey   Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
#
#                  Salary
# Name
# Raul Neto      900000.0
# Tibor Pleiss  2900000.0
# Jeff Withey    947276.0

# %%
df
# Out:
#                                            Team  Number Position   Age Height  \
# Name
# Avery Bradley                    Boston Celtics     0.0       PG  25.0    6-2
# Jae Crowder                      Boston Celtics    99.0       SF  25.0    6-6
# John Holland                     Boston Celtics    30.0       SG  27.0    6-5
# R.J. Hunter                      Boston Celtics    28.0       SG  22.0    6-5
# Jonas Jerebko                    Boston Celtics     8.0       PF  29.0   6-10
# Amir Johnson                     Boston Celtics    90.0       PF  29.0    6-9
# Jordan Mickey                    Boston Celtics    55.0       PF  21.0    6-8
# Kelly Olynyk                     Boston Celtics    41.0        C  25.0    7-0
# Terry Rozier                     Boston Celtics    12.0       PG  22.0    6-2
# Marcus Smart                     Boston Celtics    36.0       PG  22.0    6-4
# Jared Sullinger                  Boston Celtics     7.0        C  24.0    6-9
# ...

# %%
df.iloc[10:20]
# Out:
#                                    Team  Number Position   Age Height  Weight  \
# Name
# Jared Sullinger          Boston Celtics     7.0        C  24.0    6-9   260.0
# Isaiah Thomas            Boston Celtics     4.0       PG  27.0    5-9   185.0
# Evan Turner              Boston Celtics    11.0       SG  27.0    6-7   220.0
# James Young              Boston Celtics    13.0       SG  20.0    6-6   215.0
# Tyler Zeller             Boston Celtics    44.0        C  26.0    7-0   253.0
# Bojan Bogdanovic          Brooklyn Nets    44.0       SG  27.0    6-8   216.0
# Markel Brown              Brooklyn Nets    22.0       SG  24.0    6-3   190.0
# Wayne Ellington           Brooklyn Nets    21.0       SG  28.0    6-4   200.0
# Rondae Hollis-Jefferson   Brooklyn Nets    24.0       SG  21.0    6-7   220.0
# Jarrett Jack              Brooklyn Nets     2.0       PG  32.0    6-3   200.0
#
#                                 College     Salary
# Name
# ...

# %%
df.head(11)
# Out:
#                            Team  Number Position   Age Height  Weight  \
# Name
# Avery Bradley    Boston Celtics     0.0       PG  25.0    6-2   180.0
# Jae Crowder      Boston Celtics    99.0       SF  25.0    6-6   235.0
# John Holland     Boston Celtics    30.0       SG  27.0    6-5   205.0
# R.J. Hunter      Boston Celtics    28.0       SG  22.0    6-5   185.0
# Jonas Jerebko    Boston Celtics     8.0       PF  29.0   6-10   231.0
# Amir Johnson     Boston Celtics    90.0       PF  29.0    6-9   240.0
# Jordan Mickey    Boston Celtics    55.0       PF  21.0    6-8   235.0
# Kelly Olynyk     Boston Celtics    41.0        C  25.0    7-0   238.0
# Terry Rozier     Boston Celtics    12.0       PG  22.0    6-2   190.0
# Marcus Smart     Boston Celtics    36.0       PG  22.0    6-4   220.0
# Jared Sullinger  Boston Celtics     7.0        C  24.0    6-9   260.0
#
#                            College      Salary
# Name
# Avery Bradley                Texas   7730337.0
# ...

# %%
df.rename(columns={'Age':'Present_Age'})
# Out:
#                                            Team  Number Position  Present_Age  \
# Name
# Avery Bradley                    Boston Celtics     0.0       PG         25.0
# Jae Crowder                      Boston Celtics    99.0       SF         25.0
# John Holland                     Boston Celtics    30.0       SG         27.0
# R.J. Hunter                      Boston Celtics    28.0       SG         22.0
# Jonas Jerebko                    Boston Celtics     8.0       PF         29.0
# Amir Johnson                     Boston Celtics    90.0       PF         29.0
# Jordan Mickey                    Boston Celtics    55.0       PF         21.0
# Kelly Olynyk                     Boston Celtics    41.0        C         25.0
# Terry Rozier                     Boston Celtics    12.0       PG         22.0
# Marcus Smart                     Boston Celtics    36.0       PG         22.0
# Jared Sullinger                  Boston Celtics     7.0        C         24.0
# ...

# %%
data = pd.read_csv("nba.csv", index_col ="Name" ) 
  
# changing index cols with rename() 
data.rename(index = {"Avery Bradley": "NEW NAME", 
                     "Jae Crowder":"NEW NAME 2"}, 
                                 inplace = True) 
data
# Out:
#                                            Team  Number Position   Age Height  \
# Name
# NEW NAME                         Boston Celtics     0.0       PG  25.0    6-2
# NEW NAME 2                       Boston Celtics    99.0       SF  25.0    6-6
# John Holland                     Boston Celtics    30.0       SG  27.0    6-5
# R.J. Hunter                      Boston Celtics    28.0       SG  22.0    6-5
# Jonas Jerebko                    Boston Celtics     8.0       PF  29.0   6-10
# Amir Johnson                     Boston Celtics    90.0       PF  29.0    6-9
# Jordan Mickey                    Boston Celtics    55.0       PF  21.0    6-8
# Kelly Olynyk                     Boston Celtics    41.0        C  25.0    7-0
# Terry Rozier                     Boston Celtics    12.0       PG  22.0    6-2
# Marcus Smart                     Boston Celtics    36.0       PG  22.0    6-4
# Jared Sullinger                  Boston Celtics     7.0        C  24.0    6-9
# ...

# %%
data.columns=['Team Name','Number', 'Position', 'Age', 
                'Height', 'Weight', 'Education', 'Income']

# %%
data = data.rename(index={'NEW NAME':'Sumanth','NEW NAME 2':'Deepika'})

# %%
data.dropna()
# Out:
#                                       Team Name  Number Position   Age Height  \
# Name
# Sumanth                          Boston Celtics     0.0       PG  25.0    6-2
# Deepika                          Boston Celtics    99.0       SF  25.0    6-6
# R.J. Hunter                      Boston Celtics    28.0       SG  22.0    6-5
# Jordan Mickey                    Boston Celtics    55.0       PF  21.0    6-8
# Kelly Olynyk                     Boston Celtics    41.0        C  25.0    7-0
# Terry Rozier                     Boston Celtics    12.0       PG  22.0    6-2
# Marcus Smart                     Boston Celtics    36.0       PG  22.0    6-4
# Jared Sullinger                  Boston Celtics     7.0        C  24.0    6-9
# Isaiah Thomas                    Boston Celtics     4.0       PG  27.0    5-9
# Evan Turner                      Boston Celtics    11.0       SG  27.0    6-7
# James Young                      Boston Celtics    13.0       SG  20.0    6-6
# ...

# %%
data.drop(['Jeff Withey','Shelvin Mack'])
# Out:
#                                       Team Name  Number Position   Age Height  \
# Name
# Sumanth                          Boston Celtics     0.0       PG  25.0    6-2
# Deepika                          Boston Celtics    99.0       SF  25.0    6-6
# John Holland                     Boston Celtics    30.0       SG  27.0    6-5
# R.J. Hunter                      Boston Celtics    28.0       SG  22.0    6-5
# Jonas Jerebko                    Boston Celtics     8.0       PF  29.0   6-10
# Amir Johnson                     Boston Celtics    90.0       PF  29.0    6-9
# Jordan Mickey                    Boston Celtics    55.0       PF  21.0    6-8
# Kelly Olynyk                     Boston Celtics    41.0        C  25.0    7-0
# Terry Rozier                     Boston Celtics    12.0       PG  22.0    6-2
# Marcus Smart                     Boston Celtics    36.0       PG  22.0    6-4
# Jared Sullinger                  Boston Celtics     7.0        C  24.0    6-9
# ...

# %%
data.pop('Position')
# Out:
# Name
# Sumanth                     PG
# Deepika                     SF
# John Holland                SG
# R.J. Hunter                 SG
# Jonas Jerebko               PF
# Amir Johnson                PF
# Jordan Mickey               PF
# Kelly Olynyk                 C
# Terry Rozier                PG
# Marcus Smart                PG
# Jared Sullinger              C
# Isaiah Thomas               PG
# Evan Turner                 SG
# James Young                 SG
# Tyler Zeller                 C
# Bojan Bogdanovic            SG
# Markel Brown                SG
# Wayne Ellington             SG
# Rondae Hollis-Jefferson     SG
# Jarrett Jack                PG
# Sergey Karasev              SG
# Sean Kilpatrick             SG
# Shane Larkin                PG
# Brook Lopez                  C
# Chris McCullough            PF
# Willie Reed                 PF
# Thomas Robinson             PF
# Henry Sims                   C
# Donald Sloan                PG
# Thaddeus Young              PF
# ...

# %%
data
# Out:
#                                       Team Name  Number   Age Height  Weight  \
# Name
# Sumanth                          Boston Celtics     0.0  25.0    6-2   180.0
# Deepika                          Boston Celtics    99.0  25.0    6-6   235.0
# John Holland                     Boston Celtics    30.0  27.0    6-5   205.0
# R.J. Hunter                      Boston Celtics    28.0  22.0    6-5   185.0
# Jonas Jerebko                    Boston Celtics     8.0  29.0   6-10   231.0
# Amir Johnson                     Boston Celtics    90.0  29.0    6-9   240.0
# Jordan Mickey                    Boston Celtics    55.0  21.0    6-8   235.0
# Kelly Olynyk                     Boston Celtics    41.0  25.0    7-0   238.0
# Terry Rozier                     Boston Celtics    12.0  22.0    6-2   190.0
# Marcus Smart                     Boston Celtics    36.0  22.0    6-4   220.0
# Jared Sullinger                  Boston Celtics     7.0  24.0    6-9   260.0
# ...

# %%
data.sample(frac=0.25)
# Out:
#                                     Team Name  Number   Age Height  Weight  \
# Name
# Isaiah Canaan              Philadelphia 76ers     0.0  25.0    6-0   201.0
# Devyn Marble                    Orlando Magic    11.0  23.0    6-6   200.0
# Monta Ellis                    Indiana Pacers    11.0  30.0    6-3   185.0
# Isaiah Thomas                  Boston Celtics     4.0  27.0    5-9   185.0
# C.J. McCollum          Portland Trail Blazers     3.0  24.0    6-4   200.0
# Wesley Matthews              Dallas Mavericks    23.0  29.0    6-5   220.0
# Jerami Grant               Philadelphia 76ers    39.0  22.0    6-8   210.0
# Nick Young                 Los Angeles Lakers     0.0  31.0    6-7   210.0
# Derrick Rose                    Chicago Bulls     1.0  27.0    6-3   190.0
# Alec Burks                          Utah Jazz    10.0  24.0    6-6   214.0
# Kristaps Porzingis            New York Knicks     6.0  20.0    7-3   240.0
# ...

# %%
data.sample(n=1)
# Out:
#                       Team Name  Number   Age Height  Weight      Income
# Name
# Wilson Chandler  Denver Nuggets    21.0  29.0    6-8   225.0  10449438.0

# %%
data.nsmallest(5,'Weight')
# Out:
#                              Team Name  Number   Age Height  Weight     Income
# Name
# Aaron Brooks             Chicago Bulls     0.0  31.0    6-0   161.0  2250000.0
# Bryce Cotton         Memphis Grizzlies     8.0  23.0    6-1   165.0   700902.0
# Briante Weber               Miami Heat    12.0  23.0    6-2   165.0        NaN
# Brandon Jennings         Orlando Magic    55.0  26.0    6-1   169.0  8344497.0
# Tim Frazier       New Orleans Pelicans     2.0  25.0    6-1   170.0   845059.0

# %%
data.nlargest(5,'Income')
# Out:
#                            Team Name  Number   Age Height  Weight      Income
# Name
# Kobe Bryant       Los Angeles Lakers    24.0  37.0    6-6   212.0  25000000.0
# LeBron James     Cleveland Cavaliers    23.0  31.0    6-8   250.0  22970500.0
# Carmelo Anthony      New York Knicks     7.0  32.0    6-8   240.0  22875000.0
# Dwight Howard        Houston Rockets    12.0  30.0   6-11   265.0  22359364.0
# Chris Bosh                Miami Heat     1.0  32.0   6-11   235.0  22192730.0

# %%
data.shape
# Out:
# (458, 6)

# %%
data.ndim
# Out:
# 2

# %%
data.size
# Out:
# 2748

# %%
import pandas as pd
df= pd.read_csv('employees.csv')
value = df['First Name'].duplicated()
df[value]
# Out:
#       First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 23           NaN    Male   6/14/2012         4:19 PM  125792    5.042
# 25           NaN    Male   10/8/2012         1:12 AM   37076   18.576
# 32           NaN    Male   8/21/1998         2:27 PM  122340    6.417
# 34         Jerry    Male   1/10/2004        12:56 PM   95734   19.096
# 39           NaN    Male   1/29/2016         2:33 AM  122173    7.797
# 51           NaN     NaN  12/17/2011         8:29 AM   41126   14.009
# 58       Theresa  Female   4/11/2010         7:18 AM   72670    1.481
# 62           NaN  Female   6/12/2007         5:25 PM   58112   19.414
# 63       Matthew    Male    1/2/2013        10:33 PM   35203   18.040
# 66         Nancy  Female  12/15/2012        11:57 PM  125250    2.672
# 67        Rachel  Female   8/16/1999         6:53 AM   51178    9.735
# 69         Irene     NaN   7/14/2015         4:31 PM  100863    4.382
# ...

# %%
df.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male  1/24/1998         4:47 PM  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
data= df['First Name'].duplicated(keep=False)
df[data]
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# 6         Ruby  Female   8/17/1987         4:20 PM   65476   10.012
# 7          NaN  Female   7/20/2015        10:43 AM   45906   11.598
# 9      Frances  Female    8/8/2002         6:51 AM  139852    7.524
# 10      Louise  Female   8/12/1980         9:01 AM   63241   15.132
# 11       Julie  Female  10/26/1997         3:19 PM  102508   12.637
# 12     Brandon    Male   12/1/1980         1:08 AM  112807   17.492
# 13        Gary    Male   1/27/2008        11:40 PM  109831    5.831
# 14    Kimberly  Female   1/14/1999         7:13 AM   41426   14.543
# ...

# %%
df.drop_duplicates(subset='First Name',keep=False)
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 5       Dennis    Male   4/18/1987         1:35 AM  115163   10.125
# 8       Angela  Female  11/22/2005         6:29 AM   95570   18.523
# 33        Jean  Female  12/18/1993         9:07 AM  119082   16.180
# 190      Carol  Female   3/19/1996         3:39 AM   57783    9.129
# 291      Tammy  Female  11/11/1984        10:30 AM  132839   17.463
# 495     Eugene    Male   5/24/1984        10:54 AM   81077    2.117
# 688      Brian    Male    4/7/2007        10:47 PM   93901   17.821
# 832      Keith    Male   2/12/2003         3:02 PM  120672   19.467
# 887      David    Male   12/5/2009         8:48 AM   92242   15.407
#
#     Senior Management                  Team
# 5               False                 Legal
# 8                True           Engineering
# 33              False  Business Development
# 190             False               Finance
# 291              True       Client Services
# ...

# %%
filter = df["Team"] == 'Sales'
df.where(filter,inplace=True)

# %%
df
# Out:
#     First Name Gender Start Date Last Login Time  Salary  Bonus %  \
# 0          NaN    NaN        NaN             NaN     NaN      NaN
# 1          NaN    NaN        NaN             NaN     NaN      NaN
# 2          NaN    NaN        NaN             NaN     NaN      NaN
# 3          NaN    NaN        NaN             NaN     NaN      NaN
# 4          NaN    NaN        NaN             NaN     NaN      NaN
# 5          NaN    NaN        NaN             NaN     NaN      NaN
# 6          NaN    NaN        NaN             NaN     NaN      NaN
# 7          NaN    NaN        NaN             NaN     NaN      NaN
# 8          NaN    NaN        NaN             NaN     NaN      NaN
# 9          NaN    NaN        NaN             NaN     NaN      NaN
# 10         NaN    NaN        NaN             NaN     NaN      NaN
# 11         NaN    NaN        NaN             NaN     NaN      NaN
# 12         NaN    NaN        NaN             NaN     NaN      NaN
# ...

# %%
df = pd.read_csv('employees.csv',index_col='First Name')
df
# Out:
#             Gender  Start Date Last Login Time  Salary  Bonus %  \
# First Name
# Douglas       Male    8/6/1993        12:42 PM   97308    6.945
# Thomas        Male   3/31/1996         6:53 AM   61933    4.170
# Maria       Female   4/23/1993        11:17 AM  130590   11.858
# Jerry         Male    3/4/2005         1:00 PM  138705    9.340
# Larry         Male   1/24/1998         4:47 PM  101004    1.389
# Dennis        Male   4/18/1987         1:35 AM  115163   10.125
# Ruby        Female   8/17/1987         4:20 PM   65476   10.012
# NaN         Female   7/20/2015        10:43 AM   45906   11.598
# Angela      Female  11/22/2005         6:29 AM   95570   18.523
# Frances     Female    8/8/2002         6:51 AM  139852    7.524
# Louise      Female   8/12/1980         9:01 AM   63241   15.132
# Julie       Female  10/26/1997         3:19 PM  102508   12.637
# Brandon       Male   12/1/1980         1:08 AM  112807   17.492
# ...

# %%
df.iloc[[2,3],[1,2]]
# Out:
#            Start Date Last Login Time
# First Name
# Maria       4/23/1993        11:17 AM
# Jerry        3/4/2005         1:00 PM

# %%
df
# Out:
#             Gender  Start Date Last Login Time  Salary  Bonus %  \
# First Name
# Douglas       Male    8/6/1993        12:42 PM   97308    6.945
# Thomas        Male   3/31/1996         6:53 AM   61933    4.170
# Maria       Female   4/23/1993        11:17 AM  130590   11.858
# Jerry         Male    3/4/2005         1:00 PM  138705    9.340
# Larry         Male   1/24/1998         4:47 PM  101004    1.389
# Dennis        Male   4/18/1987         1:35 AM  115163   10.125
# Ruby        Female   8/17/1987         4:20 PM   65476   10.012
# NaN         Female   7/20/2015        10:43 AM   45906   11.598
# Angela      Female  11/22/2005         6:29 AM   95570   18.523
# Frances     Female    8/8/2002         6:51 AM  139852    7.524
# Louise      Female   8/12/1980         9:01 AM   63241   15.132
# Julie       Female  10/26/1997         3:19 PM  102508   12.637
# Brandon       Male   12/1/1980         1:08 AM  112807   17.492
# ...

# %%
df = pd.read_csv('employees.csv')
fill = pd.isnull(df['Team'])
fill2 = pd.isnull(df['Gender'])
df[~fill & ~fill2]
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# 5       Dennis    Male   4/18/1987         1:35 AM  115163   10.125
# 6         Ruby  Female   8/17/1987         4:20 PM   65476   10.012
# 7          NaN  Female   7/20/2015        10:43 AM   45906   11.598
# 8       Angela  Female  11/22/2005         6:29 AM   95570   18.523
# 9      Frances  Female    8/8/2002         6:51 AM  139852    7.524
# 11       Julie  Female  10/26/1997         3:19 PM  102508   12.637
# 12     Brandon    Male   12/1/1980         1:08 AM  112807   17.492
# 13        Gary    Male   1/27/2008        11:40 PM  109831    5.831
# 14    Kimberly  Female   1/14/1999         7:13 AM   41426   14.543
# ...

# %%
import numpy as np
df.replace(to_replace=np.nan,value='No Value')
# Out:
#     First Name    Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas      Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas      Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria    Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry      Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry      Male   1/24/1998         4:47 PM  101004    1.389
# 5       Dennis      Male   4/18/1987         1:35 AM  115163   10.125
# 6         Ruby    Female   8/17/1987         4:20 PM   65476   10.012
# 7     No Value    Female   7/20/2015        10:43 AM   45906   11.598
# 8       Angela    Female  11/22/2005         6:29 AM   95570   18.523
# 9      Frances    Female    8/8/2002         6:51 AM  139852    7.524
# 10      Louise    Female   8/12/1980         9:01 AM   63241   15.132
# 11       Julie    Female  10/26/1997         3:19 PM  102508   12.637
# ...

# %%
df
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# 5       Dennis    Male   4/18/1987         1:35 AM  115163   10.125
# 6         Ruby  Female   8/17/1987         4:20 PM   65476   10.012
# 7          NaN  Female   7/20/2015        10:43 AM   45906   11.598
# 8       Angela  Female  11/22/2005         6:29 AM   95570   18.523
# 9      Frances  Female    8/8/2002         6:51 AM  139852    7.524
# 10      Louise  Female   8/12/1980         9:01 AM   63241   15.132
# 11       Julie  Female  10/26/1997         3:19 PM  102508   12.637
# 12     Brandon    Male   12/1/1980         1:08 AM  112807   17.492
# ...

# %%
gender = df['Gender'].copy()
df['First Name']=df['First Name'].str.cat(gender,sep=",")
df
# Out:
#           First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0       Douglas,Male    Male    8/6/1993        12:42 PM   97308    6.945
# 1        Thomas,Male    Male   3/31/1996         6:53 AM   61933    4.170
# 2       Maria,Female  Female   4/23/1993        11:17 AM  130590   11.858
# 3         Jerry,Male    Male    3/4/2005         1:00 PM  138705    9.340
# 4         Larry,Male    Male   1/24/1998         4:47 PM  101004    1.389
# 5        Dennis,Male    Male   4/18/1987         1:35 AM  115163   10.125
# 6        Ruby,Female  Female   8/17/1987         4:20 PM   65476   10.012
# 7                NaN  Female   7/20/2015        10:43 AM   45906   11.598
# 8      Angela,Female  Female  11/22/2005         6:29 AM   95570   18.523
# 9     Frances,Female  Female    8/8/2002         6:51 AM  139852    7.524
# 10     Louise,Female  Female   8/12/1980         9:01 AM   63241   15.132
# 11      Julie,Female  Female  10/26/1997         3:19 PM  102508   12.637
# ...

# %%
s = pd.Series(['a1','b2','c3'])
n = s.str.extract(r'([abc])(\d)')
n
# Out:
#    0  1
# 0  a  1
# 1  b  2
# 2  c  3

# %%
df = pd.Series({'a':[1,2,3,4],'b':[2,3,4,5]})
df
# Out:
# a    [1, 2, 3, 4]
# b    [2, 3, 4, 5]
# dtype: object

# %%
df = pd.DataFrame({'a':[1,2,3,4],'b':[2,3,4,5]})
df
# Out:
#    a  b
# 0  1  2
# 1  2  3
# 2  3  4
# 3  4  5
